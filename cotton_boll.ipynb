# %% [markdown]
# <a href="https://colab.research.google.com/github/NAGULKS/Researchproject/blob/main/cotton_boll.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Importing Packages

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/cotton_boll/cotton_boll_dataset.zip -d ./
# Out:
# Archive:  /content/drive/MyDrive/cotton_boll/cotton_boll_dataset.zip
#    creating: ./cotton_boll/
#    creating: ./cotton_boll/train/
#   inflating: ./cotton_boll/train/boll_080_034.jpg
#   inflating: ./cotton_boll/train/boll_125_003.jpg
#   inflating: ./cotton_boll/train/boll_001_005.jpg
#   inflating: ./cotton_boll/train/boll_001_009.jpg
#   inflating: ./cotton_boll/train/boll_001_056.jpg
#   inflating: ./cotton_boll/train/boll_002_017.jpg
#   inflating: ./cotton_boll/train/boll_002_022.jpg
#   inflating: ./cotton_boll/train/boll_002_023.jpg
#   inflating: ./cotton_boll/train/boll_005_019.jpg
#   inflating: ./cotton_boll/train/boll_006_021.jpg
#   inflating: ./cotton_boll/train/boll_006_023.jpg
#   inflating: ./cotton_boll/train/boll_006_025.jpg
#   inflating: ./cotton_boll/train/boll_007_012.jpg
#   inflating: ./cotton_boll/train/boll_008_005.jpg
#   inflating: ./cotton_boll/train/boll_010_027.jpg
#   inflating: ./cotton_boll/train/boll_011_000.jpg
# ...

# %%
import os
import IPython.display as ipd
import matplotlib.pyplot as plt#graph plotting
import numpy as np#Array or Multi dimi. arrays
import pandas as pd#Reading files and sving it as tablur format
import time
from collections import Counter, OrderedDict#[1,2,3,3]
import cv2#opencv - python - Image processing- short form -cv2
from google.colab.patches import cv2_imshow#Is used for printing the images
import random#Generating random variables or values
import seaborn as sns#graph plotting

 #sklearn - scikit-learn - form machine learning algorithms
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.utils import class_weight
from sklearn.utils.class_weight import compute_class_weight


import tensorflow as tf
import keras
from tensorflow.keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, Conv1D, MaxPooling2D, MaxPooling1D, LeakyReLU, Conv2DTranspose, Concatenate
from tensorflow.keras.optimizers import Adam,SGD,Adagrad,Adadelta,RMSprop,Adamax, Nadam
from keras.callbacks import ModelCheckpoint
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ReduceLROnPlateau
from keras.models import load_model
from keras.layers import Input
from keras.layers import concatenate, add
#Keras And Tensorflow - Neural Network | Keras-Frontend, Tensorflow - Backend
from keras.applications.vgg16 import VGG16
from keras.applications.vgg16 import preprocess_input
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array
from keras.models import Model
from keras import backend as K
from matplotlib import pyplot
from numpy import expand_dims

from tqdm import tqdm_notebook as tq # Progressing bar

import warnings
warnings.filterwarnings("ignore")

try:
    from tensorflow.python.util import module_wrapper as deprecation
except ImportError:
    from tensorflow.python.util import deprecation_wrapper as deprecation
deprecation._PER_MODULE_WARNING_LIMIT = 0

from tensorflow.python.util import deprecation
deprecation._PRINT_DEPRECATION_WARNINGS = False

from sklearn.model_selection import train_test_split
import pickle
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
import IPython.display as ipd
import librosa
from matplotlib import pyplot as plt
import numpy as np
import librosa.display
import os
import time
from sklearn.preprocessing import LabelEncoder
import pandas as pd
from collections import Counter
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
import numpy as np
from matplotlib import pyplot as plt
import joblib
#from joblib import dump, load
from sklearn.model_selection import StratifiedKFold
from sklearn.naive_bayes import MultinomialNB
import pickle
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import SGDClassifier
import warnings
warnings.filterwarnings("ignore")
from sklearn import metrics
import json
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import Ridge, Lasso, ElasticNet
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.exceptions import NotFittedError
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

import os
import IPython.display as ipd
import matplotlib.pyplot as plt#graph plotting
import numpy as np#Array or Multi dimi. arrays
import pandas as pd#Reading files and sving it as tablur format
import time
from collections import Counter, OrderedDict#[1,2,3,3]
import cv2#opencv - python - Image processing- short form -cv2
from google.colab.patches import cv2_imshow#Is used for printing the images
import random#Generating random variables or values
import seaborn as sns#graph plotting

 #sklearn - scikit-learn - form machine learning algorithms
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.utils import class_weight
from sklearn.utils.class_weight import compute_class_weight

from keras.applications import VGG16, VGG19
from tensorflow.keras import layers
import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, Conv1D, MaxPooling2D, MaxPooling1D, LeakyReLU, Conv2DTranspose, Concatenate
from tensorflow.keras.optimizers import Adam,SGD,Adagrad,Adadelta,RMSprop,Adamax, Nadam
from keras.callbacks import ModelCheckpoint
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ReduceLROnPlateau
from keras.models import load_model
from keras.layers import Input
from keras.layers import concatenate, add
#Keras And Tensorflow - Neural Network | Keras-Frontend, Tensorflow - Backend
from keras.applications.vgg16 import VGG16
from keras.applications.vgg16 import preprocess_input
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array
from keras.models import Model
from keras import backend as K
from matplotlib import pyplot
from numpy import expand_dims

from tqdm import tqdm_notebook as tq # Progressing bar

import warnings
warnings.filterwarnings("ignore")

try:
    from tensorflow.python.util import module_wrapper as deprecation
except ImportError:
    from tensorflow.python.util import deprecation_wrapper as deprecation
deprecation._PER_MODULE_WARNING_LIMIT = 0

from tensorflow.python.util import deprecation
deprecation._PRINT_DEPRECATION_WARNINGS = False

from sklearn.model_selection import train_test_split
import pickle
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
import IPython.display as ipd
import librosa
from matplotlib import pyplot as plt
import numpy as np
import librosa.display
import os
import time
from sklearn.preprocessing import LabelEncoder
from keras.utils import to_categorical
import pandas as pd
from collections import Counter
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
import numpy as np
from matplotlib import pyplot as plt
import joblib
#from joblib import dump, load
from sklearn.model_selection import StratifiedKFold
from sklearn.naive_bayes import MultinomialNB
import pickle
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import SGDClassifier
import warnings
warnings.filterwarnings("ignore")
from sklearn import metrics
import json
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import Ridge, Lasso, ElasticNet
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.exceptions import NotFittedError
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# !pip install keras_applications
from keras import backend
from keras.applications import imagenet_utils
from keras_applications.imagenet_utils import _obtain_input_shape
import xml.etree.ElementTree as ET
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 1.8 MB/s eta 0:00:00
# ...

# %% [markdown]
# #Analysis

# %%
import json

# %%
json_ = open('/content/cotton_boll/train/boll_cropped_mask_train_200.json')
data = json.load(json_)

# %%
type(data)
# Out:
# dict

# %%
for k, v in data.items():
    print(k)
# Out:
# boll_001_056.jpg96194
# boll_002_023.jpg110231
# boll_005_019.jpg136447
# boll_006_021.jpg152187
# boll_006_023.jpg124518
# boll_006_025.jpg134506
# boll_007_012.jpg140014
# boll_008_005.jpg137663
# boll_010_027.jpg87863
# boll_011_000.jpg123144
# boll_016_018.jpg141399
# boll_016_023.jpg132158
# boll_018_004.jpg120158
# boll_018_011.jpg115583
# boll_018_013.jpg133655
# boll_018_021.jpg100252
# boll_019_019.jpg118537
# boll_019_022.jpg105919
# boll_020_014.jpg140489
# boll_022_008.jpg111885
# boll_022_020.jpg148075
# boll_023_023.jpg133414
# boll_024_018.jpg113970
# boll_024_020.jpg148252
# boll_024_027.jpg95797
# boll_024_028.jpg96700
# boll_025_009.jpg87416
# boll_026_019.jpg168328
# boll_026_023.jpg146622
# boll_026_025.jpg152769
# boll_027_024.jpg128748
# boll_027_038.jpg74921
# boll_027_040.jpg80931
# boll_028_008.jpg56846
# boll_028_011.jpg111529
# boll_028_019.jpg120106
# boll_028_036.jpg85361
# boll_029_036.jpg135958
# boll_029_047.jpg125020
# boll_029_048.jpg121627
# ...

# %%
len(data.keys())
# Out:
# 200

# %%
train_files = os.listdir('/content/cotton_boll/train')
print(len(train_files))

for i in train_files:
  if '.json' in i:
      train_files.remove(i)

print(len(train_files))
# Out:
# 302
# 300

# %%
data['boll_001_056.jpg96194']
# Out:
# {'filename': 'boll_001_056.jpg',
#  'size': 96194,
#  'regions': [{'shape_attributes': {'name': 'polygon',
#     'all_points_x': [207, 177, 167, 161, 177, 197, 204],
#     'all_points_y': [233, 245, 244, 219, 208, 208, 222]},
#    'region_attributes': {'class': 'boll'}}],
#  'file_attributes': {}}

# %%
v['regions']
# Out:
# [{'shape_attributes': {'name': 'polygon',
#    'all_points_x': [207, 171, 169, 175, 203, 228, 225],
#    'all_points_y': [185, 203, 219, 228, 235, 233, 203]},
#   'region_attributes': {'class': 'boll'}},
#  {'shape_attributes': {'name': 'polygon',
#    'all_points_x': [371, 345, 341, 351, 364, 392, 401, 401, 391],
#    'all_points_y': [314, 322, 343, 353, 365, 363, 341, 325, 310]},
#   'region_attributes': {'class': 'boll'}},
#  {'shape_attributes': {'name': 'polygon',
#    'all_points_x': [368, 348, 333, 325, 347, 361],
#    'all_points_y': [384, 369, 383, 409, 415, 400]},
#   'region_attributes': {'class': 'boll'}},
#  {'shape_attributes': {'name': 'polygon',
#    'all_points_x': [149, 139, 141, 161, 170, 167],
#    'all_points_y': [373, 390, 405, 399, 387, 373]},
#   'region_attributes': {'class': 'boll'}},
#  {'shape_attributes': {'name': 'polygon',
#    'all_points_x': [161, 191, 205, 193, 179, 165, 145],
#    'all_points_y': [436, 441, 409, 388, 387, 401, 419]},
# ...

# %%
attr=[]
for k,v in data.items():
    for i in v['regions']:
      attr.append(i['region_attributes']['class'])

Counter(attr)
# Out:
# Counter({'boll': 496})

# %%
v = data['boll_001_056.jpg96194']
v
# Out:
# {'filename': 'boll_001_056.jpg',
#  'size': 96194,
#  'regions': [{'shape_attributes': {'name': 'polygon',
#     'all_points_x': [207, 177, 167, 161, 177, 197, 204],
#     'all_points_y': [233, 245, 244, 219, 208, 208, 222]},
#    'region_attributes': {'class': 'boll'}}],
#  'file_attributes': {}}

# %%
input_img = cv2.imread(os.path.join('/content/cotton_boll/train', v['filename']))
input_img.shape
cv2_imshow(input_img)
# Out:
# <PIL.Image.Image image mode=RGB size=500x500>

# %%
mask_img = np.zeros(input_img.shape)
cv2_imshow(mask_img)
# Out:
# <PIL.Image.Image image mode=RGB size=500x500>

# %%
pts = []
for i in v['regions']:
  for x,y in zip(i['shape_attributes']['all_points_x'], i['shape_attributes']['all_points_y']):
    pts.append([x,y])
pts
# Out:
# [[207, 233],
#  [177, 245],
#  [167, 244],
#  [161, 219],
#  [177, 208],
#  [197, 208],
#  [204, 222]]

# %%
pts = np.array(pts, np.int32)
pts
# Out:
# array([[207, 233],
#        [177, 245],
#        [167, 244],
#        [161, 219],
#        [177, 208],
#        [197, 208],
#        [204, 222]], dtype=int32)

# %%
color = (255, 255, 255)
mask_img = cv2.fillPoly(mask_img, [pts], color)

cv2_imshow(mask_img)
# Out:
# <PIL.Image.Image image mode=RGB size=500x500>

# %% [markdown]
# #Read Dataset

# %%
json_1 = open('/content/cotton_boll/train/boll_cropped_mask_train_200.json')
data1 = json.load(json_1)

json_2 = open('/content/cotton_boll/val/boll_cropped_mask_val.json')
data2 = json.load(json_2)

# %%
color = (255, 255, 255)
input_imgs = []
mask_imgs = []
shape = []

for k, v in data1.items():
  input_img = cv2.imread(os.path.join('/content/cotton_boll/train', v['filename']))
  shape.append(input_img.shape)
  mask_img = np.zeros((500,500))

  points = []
  for i in v['regions']:
    pts = []
    for x,y in zip(i['shape_attributes']['all_points_x'], i['shape_attributes']['all_points_y']):
      pts.append([x,y])

    mask_img = cv2.fillPoly(mask_img, [np.array(pts, np.int32)], color)

  input_img = cv2.resize(input_img, (224, 224))
  mask_img = cv2.resize(mask_img, (224, 224))
  mask_img[mask_img>=127] = 255
  mask_img[mask_img<127] = 0
  mask_img = mask_img.astype(np.uint8)
  mask_img = mask_img.reshape((224,224,1))

  input_imgs.append(input_img)
  mask_imgs.append(mask_img)

for k, v in data2.items():
  input_img = cv2.imread(os.path.join('/content/cotton_boll/val', v['filename']))
  shape.append(input_img.shape)
  mask_img = np.zeros((500,500))

  points = []
  for i in v['regions']:
    pts = []
    for x,y in zip(i['shape_attributes']['all_points_x'], i['shape_attributes']['all_points_y']):
      pts.append([x,y])

    mask_img = cv2.fillPoly(mask_img, [np.array(pts, np.int32)], color)

  input_img = cv2.resize(input_img, (224, 224))
  mask_img = cv2.resize(mask_img, (224, 224))
  mask_img[mask_img>=127] = 255
  mask_img[mask_img<127] = 0
  mask_img = mask_img.astype(np.uint8)
  mask_img = mask_img.reshape((224,224,1))

  input_imgs.append(input_img)
  mask_imgs.append(mask_img)

input_imgs = np.array(input_imgs)
mask_imgs = np.array(mask_imgs)
input_imgs.shape, mask_imgs.shape, Counter(shape)
# Out:
# ((250, 224, 224, 3), (250, 224, 224, 1), Counter({(500, 500, 3): 250}))

# %%
input_imgs.dtype, mask_imgs.dtype
# Out:
# (dtype('uint8'), dtype('uint8'))

# %%
index = 10
cv2_imshow(input_imgs[index]), cv2_imshow(mask_imgs[index])
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>
# <PIL.Image.Image image mode=RGB size=224x224>
# (None, None)

# %% [markdown]
# #Normalization

# %%
np.min(input_imgs), np.max(input_imgs)
# Out:
# (0, 255)

# %%
input_imgs = input_imgs/255
np.min(input_imgs), np.max(input_imgs)
# Out:
# (0.0, 1.0)

# %%
input_imgs.dtype
# Out:
# dtype('float64')

# %%
np.min(mask_imgs[index]), np.max(mask_imgs[index]), Counter(mask_imgs.flatten())
# Out:
# (0, 255, Counter({0: 11815292, 255: 728708}))

# %%
mask_imgs[mask_imgs==255] = 1
np.min(mask_imgs[index]), np.max(mask_imgs[index]), Counter(mask_imgs.flatten())
# Out:
# (0, 1, Counter({0: 11815292, 1: 728708}))

# %%
total_pixel = 11815292+728708
total_pixel
# Out:
# 12544000

# %%
bg_equality = 11815292/total_pixel
fg_equality = 728708/total_pixel
bg_equality, fg_equality
# Out:
# (0.9419078443877551, 0.0580921556122449)

# %% [markdown]
# #Calculating Class Weight

# %%
bg = np.zeros((11815292,))
bg.shape
# Out:
# (11815292,)

# %%
fg = np.ones((728708))
fg.shape
# Out:
# (728708,)

# %%
pixels = np.concatenate((bg,fg))
pixels.shape
# Out:
# (12544000,)

# %%
from sklearn.utils import class_weight
print(pixels.shape)
print(np.unique(pixels))
class_weights = class_weight.compute_class_weight(class_weight='balanced', classes=np.unique(pixels), y=pixels)
class_weights
# Out:
# (12544000,)
# [0. 1.]
# array([0.53083749, 8.60701406])

# %%
0.53083749*11815292, 8.60701406*728708
# Out:
# (6271999.9488970805, 6272000.0016344795)

# %% [markdown]
# #Mask One Hot Encoding

# %%
a = mask_imgs[0].reshape(224,224)
a.shape
# Out:
# (224, 224)

# %%
a[a==0] = [1]
a[a==1] = [0]
a.shape
# Out:
# (224, 224)

# %% [markdown]
# #Train Test Split

# %%
mask_imgs.dtype
# Out:
# dtype('uint8')

# %%
mask_imgs = mask_imgs.astype(np.int32)
mask_imgs.dtype
# Out:
# dtype('int32')

# %%
(trainX, testX, trainY, testY) = train_test_split(input_imgs,
    mask_imgs, test_size=0.2, random_state=42)

# %%
print(trainX.dtype)
print(testX.dtype)
print(trainY.dtype)
print(testY.dtype)
# Out:
# float64
# float64
# int32
# int32

# %%
print(trainX.shape)
print(testX.shape)
print(trainY.shape)
print(testY.shape)
# Out:
# (200, 224, 224, 3)
# (50, 224, 224, 3)
# (200, 224, 224, 1)
# (50, 224, 224, 1)

# %% [markdown]
# #CNN-Conv. Neural Netawoks

# %%
input = Input((224, 224, 3))
c0 = Conv2D(filters=64,kernel_size=(3,3),padding="same", activation="relu")(input)
c0 = Conv2D(filters=64,kernel_size=(3,3),padding="same", activation="relu")(c0)
m0 = MaxPooling2D(pool_size=(2,2),strides=(2,2))(c0)
d0 = Dropout(0.2)(m0)

c1 = Conv2D(filters=128, kernel_size=(3,3), padding="same", activation="relu")(d0)
c1 = Conv2D(filters=128, kernel_size=(3,3), padding="same", activation="relu")(c1)
m1 = MaxPooling2D(pool_size=(2,2),strides=(2,2))(c1)
d1 = Dropout(0.3)(m1)

c2 = Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu")(d1)
c2 = Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu")(c2)
c2 = Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu")(c2)
m2 = MaxPooling2D(pool_size=(2,2),strides=(2,2))(c2)
d2 = Dropout(0.3)(m2)

c3 = Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu")(d2)
c3 = Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu")(c3)
c3 = Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu")(c3)
m3 = MaxPooling2D(pool_size=(2,2),strides=(2,2))(c3)
d3 = Dropout(0.4)(m3)

c4 = Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu")(d3)
c4 = Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu")(c4)
c4 = Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu")(c4)
m4 = MaxPooling2D(pool_size=(2,2),strides=(2,2))(c4)
d4 = Dropout(0.3)(m4)

at = tf.keras.layers.Attention()([d4, d4])
dc0 = Conv2DTranspose(512, (3, 3), strides = (2, 2), padding = 'same')(at)
dc0 = concatenate([dc0, c4])
d5 = Dropout(0.4)(dc0)
dec0 = Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu")(d5)
dec0 = Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu")(dec0)

dc1 = Conv2DTranspose(256, (3, 3), strides = (2, 2), padding = 'same')(dec0)
dc1 = concatenate([dc1, c3])
d6 = Dropout(0.4)(dc1)
dec1 = Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu")(d6)
dec1 = Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu")(dec1)

dc2 = Conv2DTranspose(128, (3, 3), strides = (2, 2), padding = 'same')(dec1)
dc2 = concatenate([dc2, c2])
d7 = Dropout(0.4)(dc2)
dec2 = Conv2D(filters=128, kernel_size=(3,3), padding="same", activation="relu")(d7)
dec2 = Conv2D(filters=128, kernel_size=(3,3), padding="same", activation="relu")(dec2)

dc3 = Conv2DTranspose(64, (3, 3), strides = (2, 2), padding = 'same')(dec2)
dc3 = concatenate([dc3, c1])
d8 = Dropout(0.4)(dc3)
dec3 = Conv2D(filters=64, kernel_size=(3,3), padding="same", activation="relu")(d8)
dec3 = Conv2D(filters=64, kernel_size=(3,3), padding="same", activation="relu")(dec3)

dc4 = Conv2DTranspose(32, (3, 3), strides = (2, 2), padding = 'same')(dec3)
dc4 = concatenate([dc4, c0])
d9 = Dropout(0.4)(dc4)
dec4 = Conv2D(filters=32, kernel_size=(3,3), padding="same", activation="relu")(d9)
dec4 = Conv2D(filters=2, kernel_size=(3,3), padding="same", activation="softmax")(dec4)

model = Model(inputs=[input], outputs=[dec4])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 224, 224, 64)         1792      ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 224, 224, 64)         36928     ['conv2d[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 112, 112, 64)         0         ['conv2d_1[0][0]']
#  D)
#
#  dropout (Dropout)           (None, 112, 112, 64)         0         ['max_pooling2d[0][0]']
#
#  conv2d_2 (Conv2D)           (None, 112, 112, 128)        73856     ['dropout[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 112, 112, 128)        147584    ['conv2d_2[0][0]']
#
#  max_pooling2d_1 (MaxPoolin  (None, 56, 56, 128)          0         ['conv2d_3[0][0]']
#  g2D)
#
# ...

# %% [markdown]
# #F1 Function - Calculating Accuracy

# %%
from keras.callbacks import Callback,ModelCheckpoint
from keras.models import Sequential,load_model
from keras.layers import Dense, Dropout
import keras.backend as K
def get_f1(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

# %% [markdown]
# #Loss Function - Calculating Errors

# %% [markdown]
# ##steps

# %%
true = np.array([[1, 0], [0, 1]])
true = true.flatten()
pred = np.array([[0.90, 0.1], [0.8, 0.2], [0.2, 0.8], [0.9, 0.1]])

true, pred
# Out:
# (array([1, 0, 0, 1]),
#  array([[0.9, 0.1],
#         [0.8, 0.2],
#         [0.2, 0.8],
#         [0.9, 0.1]]))

# %%
weightsList = np.array([0.53083749, 8.60701406])

sample_weightsList = weightsList[true]
sample_weightsList
# Out:
# array([8.60701406, 0.53083749, 0.53083749, 8.60701406])

# %%
loss = keras.losses.sparse_categorical_crossentropy(true,pred)
loss
# Out:
# <tf.Tensor: shape=(4,), dtype=float64, numpy=array([2.30258509, 0.22314355, 1.60943791, 2.30258509])>

# %%
loss.shape, sample_weightsList.shape
# Out:
# (TensorShape([4]), (4,))

# %%
loss*sample_weightsList
# Out:
# <tf.Tensor: shape=(4,), dtype=float64, numpy=array([19.81838227,  0.11845296,  0.85434998, 19.81838227])>

# %%
2.30258509*8.60701406, 0.22314355*0.53083749, 1.60943791*0.53083749, 2.30258509*8.60701406
# Out:
# (19.818382243976362,
#  0.1184529619916895,
#  0.8543499804552459,
#  19.818382243976362)

# %%
true = tf.constant([[[[1], [0]], [[0], [1]]]])
weightsList = K.constant([0.53083749, 8.60701406])
true1 = K.reshape(true, [-1])
true1
# Out:
# <tf.Tensor: shape=(4,), dtype=int32, numpy=array([1, 0, 0, 1], dtype=int32)>

# %%
sample_weightsList = K.gather(weightsList, true)
sample_weightsList = K.squeeze(sample_weightsList, axis=-1)
sample_weightsList
# Out:
# <tf.Tensor: shape=(1, 2, 2), dtype=float32, numpy=
# array([[[8.607014 , 0.5308375],
#         [0.5308375, 8.607014 ]]], dtype=float32)>

# %% [markdown]
# ##Function

# %%
import tensorflow as tf
def lossFunc(true, pred):
  #print('true1', true.shape, pred.shape)
  weightsList = K.constant([0.53083749, 8.60701406])
  sample_weightsList = K.gather(weightsList, true)
  sample_weightsList = K.squeeze(sample_weightsList, axis=-1)
  #print('true3', sample_weightsList)
  loss = keras.losses.sparse_categorical_crossentropy(true,pred)
  #print('l', loss.shape, loss)
  loss = loss*sample_weightsList

  return loss

true = tf.constant([[[[1], [0]], [[0], [1]]]])
pred = tf.constant([[[[0.0, 1.0], [0.1, 0.9]], [[0.7, 0.3], [0.4, 0.6]]]])
lossFunc(true, pred)
# Out:
# <tf.Tensor: shape=(1, 2, 2), dtype=float32, numpy=
# array([[[1.0260359e-06, 1.2222985e+00],
#         [1.8933643e-01, 4.3966832e+00]]], dtype=float32)>

# %% [markdown]
# #Compiling

# %%
model.compile(optimizer = Adam(0.00001), loss = lossFunc, metrics = ['accuracy', get_f1])

# %% [markdown]
# #Training-1

# %%
tf.test.is_built_with_cuda()
# Out:
# True

# %%
# %%time
#red_lr= ReduceLROnPlateau(monitor='val_loss',patience=9,verbose=2,factor=0.001,min_delta=0.01)
filepath = r"mod24_1.h5"#-{epoch:02d}-{loss:.4f}-{accuracy:.4f}-{get_f1:.4f}-{val_loss:.4f}-{val_accuracy:.4f}-{val_get_f1:.4f}.h5"
check=ModelCheckpoint(filepath = filepath, verbose = 1, save_best_only = True)

H = model.fit(
    trainX, trainY,
    validation_data=(trainX, trainY),
    callbacks = [check, ],
    batch_size=16,
    epochs=30,
    #sample_weight=cl,
    verbose=1,
  )
# Out:
# Epoch 1/30
# 13/13 [==============================] - ETA: 0s - loss: 0.6989 - accuracy: 0.6388 - get_f1: 0.1112
# Epoch 1: val_loss improved from inf to 0.69711, saving model to mod24_1.h5
# 13/13 [==============================] - 54s 2s/step - loss: 0.6989 - accuracy: 0.6388 - get_f1: 0.1112 - val_loss: 0.6971 - val_accuracy: 0.6681 - val_get_f1: 0.1120
# Epoch 2/30
# 13/13 [==============================] - ETA: 0s - loss: 0.6958 - accuracy: 0.5469 - get_f1: 0.1087
# Epoch 2: val_loss improved from 0.69711 to 0.69491, saving model to mod24_1.h5
# 13/13 [==============================] - 10s 749ms/step - loss: 0.6958 - accuracy: 0.5469 - get_f1: 0.1087 - val_loss: 0.6949 - val_accuracy: 0.3706 - val_get_f1: 0.1120
# Epoch 3/30
# 13/13 [==============================] - ETA: 0s - loss: 0.6935 - accuracy: 0.4520 - get_f1: 0.1110
# Epoch 3: val_loss improved from 0.69491 to 0.69262, saving model to mod24_1.h5
# ...

# %%
7168*224
# Out:
# 1605632

# %% [markdown]
# ##Accuracy Plot

# %%
plt.plot(H.history['accuracy'])
plt.plot(H.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %% [markdown]
# ##Loss Plot

# %%
plt.plot(H.history['loss'])
plt.plot(H.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
# !cp 'mod24_1.h5' '/content/drive/MyDrive/cotton_boll'

# %% [markdown]
# #Training-2

# %%
tf.test.is_built_with_cuda()
# Out:
# True

# %%
model = load_model("/content/drive/MyDrive/cotton_boll/mod24_1.h5", custom_objects={'lossFunc': lossFunc, 'get_f1' : get_f1})
model.compile(optimizer = Adam(0.00001), loss = lossFunc, metrics = ['accuracy', get_f1])

# %%
# %%time
#red_lr= ReduceLROnPlateau(monitor='val_loss',patience=9,verbose=2,factor=0.001,min_delta=0.01)
filepath = r"mod24_2.h5"#-{epoch:02d}-{loss:.4f}-{accuracy:.4f}-{get_f1:.4f}-{val_loss:.4f}-{val_accuracy:.4f}-{val_get_f1:.4f}.h5"
check=ModelCheckpoint(filepath = filepath, verbose = 1, save_best_only = True)

H = model.fit(
    trainX, trainY,
    validation_data=(trainX, trainY),
    callbacks = [check, ],
    batch_size=16,
    epochs=30,
    #sample_weight=cl,
    verbose=1,
  )
# Out:
# Epoch 1/30
# 13/13 [==============================] - ETA: 0s - loss: 0.4450 - accuracy: 0.8702 - get_f1: 0.1106
# Epoch 1: val_loss improved from inf to 0.49770, saving model to mod24_2.h5
# 13/13 [==============================] - 22s 840ms/step - loss: 0.4450 - accuracy: 0.8702 - get_f1: 0.1106 - val_loss: 0.4977 - val_accuracy: 0.9183 - val_get_f1: 0.1120
# Epoch 2/30
# 13/13 [==============================] - ETA: 0s - loss: 0.4269 - accuracy: 0.8703 - get_f1: 0.1100
# Epoch 2: val_loss improved from 0.49770 to 0.47871, saving model to mod24_2.h5
# 13/13 [==============================] - 11s 846ms/step - loss: 0.4269 - accuracy: 0.8703 - get_f1: 0.1100 - val_loss: 0.4787 - val_accuracy: 0.9120 - val_get_f1: 0.1120
# Epoch 3/30
# 13/13 [==============================] - ETA: 0s - loss: 0.4205 - accuracy: 0.8752 - get_f1: 0.1105
# Epoch 3: val_loss did not improve from 0.47871
# ...

# %%
7168*224
# Out:
# 1605632

# %% [markdown]
# ##Accuracy Plot

# %%
plt.plot(H.history['accuracy'])
plt.plot(H.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %% [markdown]
# ##Loss Plot

# %%
plt.plot(H.history['loss'])
plt.plot(H.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
# !cp 'mod24_1.h5' '/content/drive/MyDrive/cotton_boll'

# %% [markdown]
# #Inference

# %%
from keras.callbacks import Callback,ModelCheckpoint
from keras.models import Sequential,load_model
from keras.layers import Dense, Dropout
import keras.backend as K
def get_f1(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

import tensorflow as tf
def lossFunc(true, pred):
  #print('true1', true.shape, pred.shape)
  weightsList = K.constant([0.53083749, 8.60701406])
  sample_weightsList = K.gather(weightsList, true)
  sample_weightsList = K.squeeze(sample_weightsList, axis=-1)
  #print('true3', sample_weightsList)
  loss = keras.losses.sparse_categorical_crossentropy(true,pred)
  #print('l', loss.shape, loss)
  loss = loss*sample_weightsList

  return loss

model = load_model("/content/drive/MyDrive/cotton_boll/mod24_1.h5", custom_objects={'lossFunc': lossFunc, 'get_f1' : get_f1})

# %%
json_1 = open('/content/cotton_boll/train/boll_cropped_mask_train_200.json')
data1 = json.load(json_1)

json_2 = open('/content/cotton_boll/val/boll_cropped_mask_val.json')
data2 = json.load(json_2)

# %%
color = (255, 255, 255)
input_imgs = []
mask_imgs = []
shape = []

for k, v in data1.items():
  input_img = cv2.imread(os.path.join('/content/cotton_boll/train', v['filename']))
  shape.append(input_img.shape)
  mask_img = np.zeros((500,500))

  points = []
  for i in v['regions']:
    pts = []
    for x,y in zip(i['shape_attributes']['all_points_x'], i['shape_attributes']['all_points_y']):
      pts.append([x,y])

    mask_img = cv2.fillPoly(mask_img, [np.array(pts, np.int32)], color)

  input_img = cv2.resize(input_img, (224, 224))
  mask_img = cv2.resize(mask_img, (224, 224))
  mask_img[mask_img>=127] = 255
  mask_img[mask_img<127] = 0
  mask_img = mask_img.astype(np.uint8)
  mask_img = mask_img.reshape((224,224,1))

  input_imgs.append(input_img)
  mask_imgs.append(mask_img)

for k, v in data2.items():
  input_img = cv2.imread(os.path.join('/content/cotton_boll/val', v['filename']))
  shape.append(input_img.shape)
  mask_img = np.zeros((500,500))

  points = []
  for i in v['regions']:
    pts = []
    for x,y in zip(i['shape_attributes']['all_points_x'], i['shape_attributes']['all_points_y']):
      pts.append([x,y])

    mask_img = cv2.fillPoly(mask_img, [np.array(pts, np.int32)], color)

  input_img = cv2.resize(input_img, (224, 224))
  mask_img = cv2.resize(mask_img, (224, 224))
  mask_img[mask_img>=127] = 255
  mask_img[mask_img<127] = 0
  mask_img = mask_img.astype(np.uint8)
  mask_img = mask_img.reshape((224,224,1))

  input_imgs.append(input_img)
  mask_imgs.append(mask_img)

input_imgs = np.array(input_imgs)
mask_imgs = np.array(mask_imgs)
input_imgs.shape, mask_imgs.shape, Counter(shape)
# Out:
# ((250, 224, 224, 3), (250, 224, 224, 1), Counter({(500, 500, 3): 250}))

# %%
index = 100
image = input_imgs[index].copy()
output_image = input_imgs[index].copy()
cv2_imshow(image)
cv2_imshow(mask_imgs[index])
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
image = image/255
image = np.array([image])
image.shape
# Out:
# (1, 224, 224, 3)

# %%
pred = model.predict(image)
pred.shape
# Out:
# 1/1 [==============================] - 2s 2s/step
# (1, 224, 224, 2)

# %%
bg = pred[0][:,:,0]
fg = pred[0][:,:,1]

# %%
fg = fg*255
fg[fg<127] = 0
fg[fg>=127] = 255

# %%
cv2_imshow(bg)
# Out:
# <PIL.Image.Image image mode=L size=224x224>

# %%
cv2_imshow(fg)
# Out:
# <PIL.Image.Image image mode=L size=224x224>

# %%
fg.dtype
# Out:
# dtype('float32')

# %%
fg = fg.astype('uint8')
fg.dtype
# Out:
# dtype('uint8')

# %%
contours, hierarchy = cv2.findContours(fg, cv2.RETR_TREE, cv2.CHAIN_APPROX_NONE)

output_image = cv2.drawContours(output_image, contours, -1, (0, 255, 0), 3)
cv2_imshow(output_image)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>
